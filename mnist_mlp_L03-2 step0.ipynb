# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from utils import mnist

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_loader, test_loader = mnist()

# %%
class Net(nn.Module):
    def __init__(self, log_softmax=False):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.fc2 = nn.Linear(128, 10)
        self.log_softmax = log_softmax
        self.optim = optim.SGD(self.parameters(), lr=1.0)
        
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = torch.sigmoid(self.fc1(x))
        x = self.fc2(x)
        if self.log_softmax:
            x = F.log_softmax(x, dim=1)
        else:
            x = torch.log(F.softmax(x, dim=1))
        return x
    
    def loss(self, output, target, **kwargs):
        self._loss = F.nll_loss(output, target, **kwargs)
        return self._loss

# %%
def train(epoch, models):
    for batch_idx, (data, target) in enumerate(train_loader):
        for k, model in models.items():
            model.optim.zero_grad()
            output = model(data)
            loss = model.loss(output, target)
            loss.backward()
            model.optim.step()
            
        if batch_idx % 200 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader))
            losses = ' '.join(['{}: {:.6f}'.format(i, m._loss.item()) for i, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader))
        losses = ' '.join(['{}: {:.6f}'.format(i, m._loss.item()) for i, m in models.items()])
        print(line + losses)

# %%
def test(models, log=None):
    test_size = len(test_loader.dataset)
    avg_lambda = lambda l: 'Loss: {:.4f}'.format(l)
    acc_lambda = lambda c, p: 'Accuracy: {}/{} ({:.0f}%)'.format(c, test_size, p)
    line = lambda i, l, c, p: '{}: '.format(i) + avg_lambda(l) + '\t' + acc_lambda(c, p)
    
    test_loss = {k: 0. for k in models}
    correct = {k: 0. for k in models}
    with torch.no_grad():
        for data, target in test_loader:
            for k, m in models.items():
                output = m(data)
                test_loss[k] += m.loss(output, target, reduction='sum').item() # sum up batch loss
                pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
                correct[k] += pred.eq(target.data.view_as(pred)).cpu().sum().item()
    
    for k in models:
        test_loss[k] /= test_size
    correct_pct = {k: 100. * correct[k] / test_size for k in correct}
    lines = '\n'.join([line(i, test_loss[i], correct[i], correct_pct[i]) for i in models]) + '\n'
    report = 'Test set:\n' + lines
    if log is not None:
        for k in models:
            log[k].append((test_loss[k], correct_pct[k]))
    print(report)

# %%
models = {'softmax' : Net(), 'log_softmax' : Net(True)}
test_log = {k: [] for k in models}

epochs = 100
for epoch in range(1, epochs+1):
    for model in models.values():
        model.train()
    train(epoch, models)
    for model in models.values():
        model.eval()
    test(models, test_log)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Losses softmax: 2.326781 log_softmax: 2.265284
# Train Epoch: 1 [10000/60000 (17%)]	Losses softmax: 0.237820 log_softmax: 0.241340
# Train Epoch: 1 [20000/60000 (33%)]	Losses softmax: 0.231649 log_softmax: 0.217126
# Train Epoch: 1 [30000/60000 (50%)]	Losses softmax: 0.121032 log_softmax: 0.154159
# Train Epoch: 1 [40000/60000 (67%)]	Losses softmax: 0.121187 log_softmax: 0.138780
# Train Epoch: 1 [50000/60000 (83%)]	Losses softmax: 0.099783 log_softmax: 0.123326
# Train Epoch: 1 [60000/60000 (100%)]	Losses softmax: 0.205731 log_softmax: 0.293933
# Test set:
# softmax: Loss: 0.1168	Accuracy: 9653.0/10000 (97%)
# log_softmax: Loss: 0.1154	Accuracy: 9646.0/10000 (96%)
#
# Train Epoch: 2 [0/60000 (0%)]	Losses softmax: 0.108391 log_softmax: 0.134507
# Train Epoch: 2 [10000/60000 (17%)]	Losses softmax: 0.065974 log_softmax: 0.070084
# Train Epoch: 2 [20000/60000 (33%)]	Losses softmax: 0.113125 log_softmax: 0.233639
# Train Epoch: 2 [30000/60000 (50%)]	Losses softmax: 0.084615 log_softmax: 0.091550
# Train Epoch: 2 [40000/60000 (67%)]	Losses softmax: 0.016207 log_softmax: 0.020731
# Train Epoch: 2 [50000/60000 (83%)]	Losses softmax: 0.126450 log_softmax: 0.106307
# Train Epoch: 2 [60000/60000 (100%)]	Losses softmax: 0.125354 log_softmax: 0.100907
# Test set:
# softmax: Loss: 0.0974	Accuracy: 9708.0/10000 (97%)
# log_softmax: Loss: 0.0973	Accuracy: 9700.0/10000 (97%)
#
# Train Epoch: 3 [0/60000 (0%)]	Losses softmax: 0.019572 log_softmax: 0.011297
# Train Epoch: 3 [10000/60000 (17%)]	Losses softmax: 0.091530 log_softmax: 0.090600
# Train Epoch: 3 [20000/60000 (33%)]	Losses softmax: 0.010249 log_softmax: 0.025873
# Train Epoch: 3 [30000/60000 (50%)]	Losses softmax: 0.081684 log_softmax: 0.088518
# Train Epoch: 3 [40000/60000 (67%)]	Losses softmax: 0.029706 log_softmax: 0.040922
# Train Epoch: 3 [50000/60000 (83%)]	Losses softmax: 0.029193 log_softmax: 0.056083
# Train Epoch: 3 [60000/60000 (100%)]	Losses softmax: 0.031703 log_softmax: 0.043928
# Test set:
# softmax: Loss: 0.0896	Accuracy: 9697.0/10000 (97%)
# log_softmax: Loss: 0.0872	Accuracy: 9721.0/10000 (97%)
#
# Train Epoch: 4 [0/60000 (0%)]	Losses softmax: 0.007574 log_softmax: 0.005461
# Train Epoch: 4 [10000/60000 (17%)]	Losses softmax: 0.012753 log_softmax: 0.011694
# Train Epoch: 4 [20000/60000 (33%)]	Losses softmax: 0.040602 log_softmax: 0.011567
# Train Epoch: 4 [30000/60000 (50%)]	Losses softmax: 0.039146 log_softmax: 0.019022
# Train Epoch: 4 [40000/60000 (67%)]	Losses softmax: 0.054622 log_softmax: 0.043759
# Train Epoch: 4 [50000/60000 (83%)]	Losses softmax: 0.095110 log_softmax: 0.115987
# Train Epoch: 4 [60000/60000 (100%)]	Losses softmax: 0.022834 log_softmax: 0.018010
# Test set:
# softmax: Loss: 0.0843	Accuracy: 9737.0/10000 (97%)
# log_softmax: Loss: 0.0805	Accuracy: 9745.0/10000 (97%)
#
# Train Epoch: 5 [0/60000 (0%)]	Losses softmax: 0.053792 log_softmax: 0.027628
# Train Epoch: 5 [10000/60000 (17%)]	Losses softmax: 0.025174 log_softmax: 0.020775
# Train Epoch: 5 [20000/60000 (33%)]	Losses softmax: 0.014969 log_softmax: 0.015099
# Train Epoch: 5 [30000/60000 (50%)]	Losses softmax: 0.006807 log_softmax: 0.007406
# Train Epoch: 5 [40000/60000 (67%)]	Losses softmax: 0.005272 log_softmax: 0.004364
# Train Epoch: 5 [50000/60000 (83%)]	Losses softmax: 0.062774 log_softmax: 0.110838
# Train Epoch: 5 [60000/60000 (100%)]	Losses softmax: 0.023341 log_softmax: 0.020625
# Test set:
# softmax: Loss: 0.0812	Accuracy: 9747.0/10000 (97%)
# log_softmax: Loss: 0.0776	Accuracy: 9753.0/10000 (98%)
#
# Train Epoch: 6 [0/60000 (0%)]	Losses softmax: 0.029482 log_softmax: 0.028596
# Train Epoch: 6 [10000/60000 (17%)]	Losses softmax: 0.018165 log_softmax: 0.060468
# Train Epoch: 6 [20000/60000 (33%)]	Losses softmax: 0.010052 log_softmax: 0.018479
# Train Epoch: 6 [30000/60000 (50%)]	Losses softmax: 0.007774 log_softmax: 0.010724
# Train Epoch: 6 [40000/60000 (67%)]	Losses softmax: 0.029973 log_softmax: 0.062256
# Train Epoch: 6 [50000/60000 (83%)]	Losses softmax: 0.029939 log_softmax: 0.009263
# Train Epoch: 6 [60000/60000 (100%)]	Losses softmax: 0.064976 log_softmax: 0.031380
# Test set:
# softmax: Loss: 0.0750	Accuracy: 9758.0/10000 (98%)
# log_softmax: Loss: 0.0753	Accuracy: 9761.0/10000 (98%)
#
# Train Epoch: 7 [0/60000 (0%)]	Losses softmax: 0.039142 log_softmax: 0.038033
# Train Epoch: 7 [10000/60000 (17%)]	Losses softmax: 0.003399 log_softmax: 0.005334
# Train Epoch: 7 [20000/60000 (33%)]	Losses softmax: 0.031113 log_softmax: 0.040050
# Train Epoch: 7 [30000/60000 (50%)]	Losses softmax: 0.014139 log_softmax: 0.009889
# Train Epoch: 7 [40000/60000 (67%)]	Losses softmax: 0.052156 log_softmax: 0.005721
# Train Epoch: 7 [50000/60000 (83%)]	Losses softmax: 0.033791 log_softmax: 0.053214
# Train Epoch: 7 [60000/60000 (100%)]	Losses softmax: 0.009208 log_softmax: 0.004434
# Test set:
# softmax: Loss: 0.0686	Accuracy: 9783.0/10000 (98%)
# log_softmax: Loss: 0.0718	Accuracy: 9804.0/10000 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Losses softmax: 0.020756 log_softmax: 0.018933
# Train Epoch: 8 [10000/60000 (17%)]	Losses softmax: 0.059827 log_softmax: 0.021671
# Train Epoch: 8 [20000/60000 (33%)]	Losses softmax: 0.018302 log_softmax: 0.036054
# Train Epoch: 8 [30000/60000 (50%)]	Losses softmax: 0.007367 log_softmax: 0.002385
# Train Epoch: 8 [40000/60000 (67%)]	Losses softmax: 0.007215 log_softmax: 0.017672
# Train Epoch: 8 [50000/60000 (83%)]	Losses softmax: 0.029132 log_softmax: 0.024709
# Train Epoch: 8 [60000/60000 (100%)]	Losses softmax: 0.004400 log_softmax: 0.007651
# Test set:
# softmax: Loss: 0.0698	Accuracy: 9792.0/10000 (98%)
# log_softmax: Loss: 0.0743	Accuracy: 9779.0/10000 (98%)
#
# Train Epoch: 9 [0/60000 (0%)]	Losses softmax: 0.004089 log_softmax: 0.012489
# Train Epoch: 9 [10000/60000 (17%)]	Losses softmax: 0.002542 log_softmax: 0.001465
# Train Epoch: 9 [20000/60000 (33%)]	Losses softmax: 0.013707 log_softmax: 0.011287
# Train Epoch: 9 [30000/60000 (50%)]	Losses softmax: 0.003528 log_softmax: 0.004032
# Train Epoch: 9 [40000/60000 (67%)]	Losses softmax: 0.034575 log_softmax: 0.019630
# Train Epoch: 9 [50000/60000 (83%)]	Losses softmax: 0.018141 log_softmax: 0.015024
# Train Epoch: 9 [60000/60000 (100%)]	Losses softmax: 0.000801 log_softmax: 0.002250
# Test set:
# softmax: Loss: 0.0708	Accuracy: 9784.0/10000 (98%)
# log_softmax: Loss: 0.0745	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 10 [0/60000 (0%)]	Losses softmax: 0.004666 log_softmax: 0.002463
# Train Epoch: 10 [10000/60000 (17%)]	Losses softmax: 0.017923 log_softmax: 0.005687
# Train Epoch: 10 [20000/60000 (33%)]	Losses softmax: 0.004034 log_softmax: 0.004470
# Train Epoch: 10 [30000/60000 (50%)]	Losses softmax: 0.003344 log_softmax: 0.017507
# Train Epoch: 10 [40000/60000 (67%)]	Losses softmax: 0.006179 log_softmax: 0.024280
# Train Epoch: 10 [50000/60000 (83%)]	Losses softmax: 0.002733 log_softmax: 0.001643
# Train Epoch: 10 [60000/60000 (100%)]	Losses softmax: 0.003109 log_softmax: 0.003147
# Test set:
# softmax: Loss: 0.0686	Accuracy: 9786.0/10000 (98%)
# log_softmax: Loss: 0.0726	Accuracy: 9786.0/10000 (98%)
#
# Train Epoch: 11 [0/60000 (0%)]	Losses softmax: 0.003334 log_softmax: 0.003071
# Train Epoch: 11 [10000/60000 (17%)]	Losses softmax: 0.005498 log_softmax: 0.004905
# Train Epoch: 11 [20000/60000 (33%)]	Losses softmax: 0.008015 log_softmax: 0.004909
# Train Epoch: 11 [30000/60000 (50%)]	Losses softmax: 0.003521 log_softmax: 0.003726
# Train Epoch: 11 [40000/60000 (67%)]	Losses softmax: 0.010029 log_softmax: 0.003348
# Train Epoch: 11 [50000/60000 (83%)]	Losses softmax: 0.003469 log_softmax: 0.001430
# Train Epoch: 11 [60000/60000 (100%)]	Losses softmax: 0.007335 log_softmax: 0.018292
# Test set:
# softmax: Loss: 0.0694	Accuracy: 9789.0/10000 (98%)
# log_softmax: Loss: 0.0721	Accuracy: 9799.0/10000 (98%)
#
# Train Epoch: 12 [0/60000 (0%)]	Losses softmax: 0.003113 log_softmax: 0.002114
# Train Epoch: 12 [10000/60000 (17%)]	Losses softmax: 0.000819 log_softmax: 0.000784
# Train Epoch: 12 [20000/60000 (33%)]	Losses softmax: 0.005968 log_softmax: 0.002166
# Train Epoch: 12 [30000/60000 (50%)]	Losses softmax: 0.004652 log_softmax: 0.001944
# Train Epoch: 12 [40000/60000 (67%)]	Losses softmax: 0.003115 log_softmax: 0.000648
# Train Epoch: 12 [50000/60000 (83%)]	Losses softmax: 0.003961 log_softmax: 0.003588
# Train Epoch: 12 [60000/60000 (100%)]	Losses softmax: 0.007903 log_softmax: 0.004434
# Test set:
# softmax: Loss: 0.0687	Accuracy: 9800.0/10000 (98%)
# log_softmax: Loss: 0.0737	Accuracy: 9795.0/10000 (98%)
#
# Train Epoch: 13 [0/60000 (0%)]	Losses softmax: 0.005226 log_softmax: 0.003268
# Train Epoch: 13 [10000/60000 (17%)]	Losses softmax: 0.102025 log_softmax: 0.086295
# Train Epoch: 13 [20000/60000 (33%)]	Losses softmax: 0.001988 log_softmax: 0.001860
# Train Epoch: 13 [30000/60000 (50%)]	Losses softmax: 0.003234 log_softmax: 0.001894
# Train Epoch: 13 [40000/60000 (67%)]	Losses softmax: 0.003544 log_softmax: 0.001554
# Train Epoch: 13 [50000/60000 (83%)]	Losses softmax: 0.005321 log_softmax: 0.003049
# Train Epoch: 13 [60000/60000 (100%)]	Losses softmax: 0.002154 log_softmax: 0.001109
# Test set:
# softmax: Loss: 0.0677	Accuracy: 9798.0/10000 (98%)
# log_softmax: Loss: 0.0733	Accuracy: 9786.0/10000 (98%)
#
# Train Epoch: 14 [0/60000 (0%)]	Losses softmax: 0.001663 log_softmax: 0.004021
# Train Epoch: 14 [10000/60000 (17%)]	Losses softmax: 0.001169 log_softmax: 0.002376
# Train Epoch: 14 [20000/60000 (33%)]	Losses softmax: 0.001612 log_softmax: 0.001915
# Train Epoch: 14 [30000/60000 (50%)]	Losses softmax: 0.002921 log_softmax: 0.002683
# Train Epoch: 14 [40000/60000 (67%)]	Losses softmax: 0.000965 log_softmax: 0.000983
# Train Epoch: 14 [50000/60000 (83%)]	Losses softmax: 0.001528 log_softmax: 0.002312
# Train Epoch: 14 [60000/60000 (100%)]	Losses softmax: 0.005939 log_softmax: 0.007015
# Test set:
# softmax: Loss: 0.0692	Accuracy: 9801.0/10000 (98%)
# log_softmax: Loss: 0.0732	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 15 [0/60000 (0%)]	Losses softmax: 0.001688 log_softmax: 0.000874
# Train Epoch: 15 [10000/60000 (17%)]	Losses softmax: 0.002509 log_softmax: 0.002177
# Train Epoch: 15 [20000/60000 (33%)]	Losses softmax: 0.001016 log_softmax: 0.000382
# Train Epoch: 15 [30000/60000 (50%)]	Losses softmax: 0.001608 log_softmax: 0.001381
# Train Epoch: 15 [40000/60000 (67%)]	Losses softmax: 0.002485 log_softmax: 0.001520
# Train Epoch: 15 [50000/60000 (83%)]	Losses softmax: 0.002555 log_softmax: 0.002323
# Train Epoch: 15 [60000/60000 (100%)]	Losses softmax: 0.001028 log_softmax: 0.006434
# Test set:
# softmax: Loss: 0.0692	Accuracy: 9809.0/10000 (98%)
# log_softmax: Loss: 0.0747	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 16 [0/60000 (0%)]	Losses softmax: 0.001601 log_softmax: 0.001352
# Train Epoch: 16 [10000/60000 (17%)]	Losses softmax: 0.000681 log_softmax: 0.000830
# Train Epoch: 16 [20000/60000 (33%)]	Losses softmax: 0.007304 log_softmax: 0.005583
# Train Epoch: 16 [30000/60000 (50%)]	Losses softmax: 0.001968 log_softmax: 0.001879
# Train Epoch: 16 [40000/60000 (67%)]	Losses softmax: 0.002524 log_softmax: 0.002690
# Train Epoch: 16 [50000/60000 (83%)]	Losses softmax: 0.001927 log_softmax: 0.001234
# Train Epoch: 16 [60000/60000 (100%)]	Losses softmax: 0.000603 log_softmax: 0.000410
# Test set:
# softmax: Loss: 0.0699	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0746	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 17 [0/60000 (0%)]	Losses softmax: 0.000890 log_softmax: 0.001530
# Train Epoch: 17 [10000/60000 (17%)]	Losses softmax: 0.000546 log_softmax: 0.000563
# Train Epoch: 17 [20000/60000 (33%)]	Losses softmax: 0.006064 log_softmax: 0.005137
# Train Epoch: 17 [30000/60000 (50%)]	Losses softmax: 0.006057 log_softmax: 0.003227
# Train Epoch: 17 [40000/60000 (67%)]	Losses softmax: 0.002272 log_softmax: 0.000853
# Train Epoch: 17 [50000/60000 (83%)]	Losses softmax: 0.003046 log_softmax: 0.002827
# Train Epoch: 17 [60000/60000 (100%)]	Losses softmax: 0.001879 log_softmax: 0.001262
# Test set:
# softmax: Loss: 0.0696	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0743	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 18 [0/60000 (0%)]	Losses softmax: 0.000851 log_softmax: 0.000678
# Train Epoch: 18 [10000/60000 (17%)]	Losses softmax: 0.003273 log_softmax: 0.002300
# Train Epoch: 18 [20000/60000 (33%)]	Losses softmax: 0.000583 log_softmax: 0.000527
# Train Epoch: 18 [30000/60000 (50%)]	Losses softmax: 0.000654 log_softmax: 0.000655
# Train Epoch: 18 [40000/60000 (67%)]	Losses softmax: 0.001407 log_softmax: 0.000612
# Train Epoch: 18 [50000/60000 (83%)]	Losses softmax: 0.002833 log_softmax: 0.002453
# Train Epoch: 18 [60000/60000 (100%)]	Losses softmax: 0.005732 log_softmax: 0.002998
# Test set:
# softmax: Loss: 0.0701	Accuracy: 9810.0/10000 (98%)
# log_softmax: Loss: 0.0741	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 19 [0/60000 (0%)]	Losses softmax: 0.000801 log_softmax: 0.002355
# Train Epoch: 19 [10000/60000 (17%)]	Losses softmax: 0.001021 log_softmax: 0.002057
# Train Epoch: 19 [20000/60000 (33%)]	Losses softmax: 0.000385 log_softmax: 0.000590
# Train Epoch: 19 [30000/60000 (50%)]	Losses softmax: 0.004543 log_softmax: 0.001705
# Train Epoch: 19 [40000/60000 (67%)]	Losses softmax: 0.001103 log_softmax: 0.001089
# Train Epoch: 19 [50000/60000 (83%)]	Losses softmax: 0.001472 log_softmax: 0.001453
# Train Epoch: 19 [60000/60000 (100%)]	Losses softmax: 0.000563 log_softmax: 0.000380
# Test set:
# softmax: Loss: 0.0701	Accuracy: 9800.0/10000 (98%)
# log_softmax: Loss: 0.0749	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 20 [0/60000 (0%)]	Losses softmax: 0.001773 log_softmax: 0.001403
# Train Epoch: 20 [10000/60000 (17%)]	Losses softmax: 0.002394 log_softmax: 0.001280
# Train Epoch: 20 [20000/60000 (33%)]	Losses softmax: 0.001241 log_softmax: 0.000637
# Train Epoch: 20 [30000/60000 (50%)]	Losses softmax: 0.001264 log_softmax: 0.001334
# Train Epoch: 20 [40000/60000 (67%)]	Losses softmax: 0.002324 log_softmax: 0.001645
# Train Epoch: 20 [50000/60000 (83%)]	Losses softmax: 0.003073 log_softmax: 0.001963
# Train Epoch: 20 [60000/60000 (100%)]	Losses softmax: 0.001582 log_softmax: 0.001435
# Test set:
# softmax: Loss: 0.0704	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0754	Accuracy: 9796.0/10000 (98%)
#
# Train Epoch: 21 [0/60000 (0%)]	Losses softmax: 0.001574 log_softmax: 0.002285
# Train Epoch: 21 [10000/60000 (17%)]	Losses softmax: 0.000906 log_softmax: 0.000655
# Train Epoch: 21 [20000/60000 (33%)]	Losses softmax: 0.001216 log_softmax: 0.002017
# Train Epoch: 21 [30000/60000 (50%)]	Losses softmax: 0.002210 log_softmax: 0.001697
# Train Epoch: 21 [40000/60000 (67%)]	Losses softmax: 0.001223 log_softmax: 0.001076
# Train Epoch: 21 [50000/60000 (83%)]	Losses softmax: 0.001013 log_softmax: 0.001105
# Train Epoch: 21 [60000/60000 (100%)]	Losses softmax: 0.001096 log_softmax: 0.000683
# Test set:
# softmax: Loss: 0.0712	Accuracy: 9800.0/10000 (98%)
# log_softmax: Loss: 0.0759	Accuracy: 9787.0/10000 (98%)
#
# Train Epoch: 22 [0/60000 (0%)]	Losses softmax: 0.004665 log_softmax: 0.003697
# Train Epoch: 22 [10000/60000 (17%)]	Losses softmax: 0.001549 log_softmax: 0.002699
# Train Epoch: 22 [20000/60000 (33%)]	Losses softmax: 0.001416 log_softmax: 0.000803
# Train Epoch: 22 [30000/60000 (50%)]	Losses softmax: 0.001196 log_softmax: 0.000377
# Train Epoch: 22 [40000/60000 (67%)]	Losses softmax: 0.001491 log_softmax: 0.000673
# Train Epoch: 22 [50000/60000 (83%)]	Losses softmax: 0.002466 log_softmax: 0.003879
# Train Epoch: 22 [60000/60000 (100%)]	Losses softmax: 0.000322 log_softmax: 0.000527
# Test set:
# softmax: Loss: 0.0720	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0767	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 23 [0/60000 (0%)]	Losses softmax: 0.000448 log_softmax: 0.000390
# Train Epoch: 23 [10000/60000 (17%)]	Losses softmax: 0.000583 log_softmax: 0.001753
# Train Epoch: 23 [20000/60000 (33%)]	Losses softmax: 0.001242 log_softmax: 0.000931
# Train Epoch: 23 [30000/60000 (50%)]	Losses softmax: 0.000335 log_softmax: 0.000219
# Train Epoch: 23 [40000/60000 (67%)]	Losses softmax: 0.001918 log_softmax: 0.001341
# Train Epoch: 23 [50000/60000 (83%)]	Losses softmax: 0.002700 log_softmax: 0.001107
# Train Epoch: 23 [60000/60000 (100%)]	Losses softmax: 0.000823 log_softmax: 0.001190
# Test set:
# softmax: Loss: 0.0711	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0767	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 24 [0/60000 (0%)]	Losses softmax: 0.002124 log_softmax: 0.003132
# Train Epoch: 24 [10000/60000 (17%)]	Losses softmax: 0.001641 log_softmax: 0.001194
# Train Epoch: 24 [20000/60000 (33%)]	Losses softmax: 0.000889 log_softmax: 0.000991
# Train Epoch: 24 [30000/60000 (50%)]	Losses softmax: 0.000866 log_softmax: 0.001494
# Train Epoch: 24 [40000/60000 (67%)]	Losses softmax: 0.001300 log_softmax: 0.001125
# Train Epoch: 24 [50000/60000 (83%)]	Losses softmax: 0.000390 log_softmax: 0.000629
# Train Epoch: 24 [60000/60000 (100%)]	Losses softmax: 0.001001 log_softmax: 0.001267
# Test set:
# softmax: Loss: 0.0720	Accuracy: 9810.0/10000 (98%)
# log_softmax: Loss: 0.0769	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 25 [0/60000 (0%)]	Losses softmax: 0.000652 log_softmax: 0.000828
# Train Epoch: 25 [10000/60000 (17%)]	Losses softmax: 0.000715 log_softmax: 0.000665
# Train Epoch: 25 [20000/60000 (33%)]	Losses softmax: 0.000193 log_softmax: 0.000391
# Train Epoch: 25 [30000/60000 (50%)]	Losses softmax: 0.001532 log_softmax: 0.001082
# Train Epoch: 25 [40000/60000 (67%)]	Losses softmax: 0.001182 log_softmax: 0.000707
# Train Epoch: 25 [50000/60000 (83%)]	Losses softmax: 0.000825 log_softmax: 0.000701
# Train Epoch: 25 [60000/60000 (100%)]	Losses softmax: 0.002076 log_softmax: 0.002738
# Test set:
# softmax: Loss: 0.0718	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0771	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 26 [0/60000 (0%)]	Losses softmax: 0.000321 log_softmax: 0.000390
# Train Epoch: 26 [10000/60000 (17%)]	Losses softmax: 0.000859 log_softmax: 0.000961
# Train Epoch: 26 [20000/60000 (33%)]	Losses softmax: 0.000352 log_softmax: 0.000381
# Train Epoch: 26 [30000/60000 (50%)]	Losses softmax: 0.000766 log_softmax: 0.001223
# Train Epoch: 26 [40000/60000 (67%)]	Losses softmax: 0.001186 log_softmax: 0.001549
# Train Epoch: 26 [50000/60000 (83%)]	Losses softmax: 0.002294 log_softmax: 0.002826
# Train Epoch: 26 [60000/60000 (100%)]	Losses softmax: 0.000506 log_softmax: 0.000420
# Test set:
# softmax: Loss: 0.0720	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0772	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 27 [0/60000 (0%)]	Losses softmax: 0.000787 log_softmax: 0.000617
# Train Epoch: 27 [10000/60000 (17%)]	Losses softmax: 0.001738 log_softmax: 0.001630
# Train Epoch: 27 [20000/60000 (33%)]	Losses softmax: 0.000864 log_softmax: 0.000978
# Train Epoch: 27 [30000/60000 (50%)]	Losses softmax: 0.000152 log_softmax: 0.000425
# Train Epoch: 27 [40000/60000 (67%)]	Losses softmax: 0.001298 log_softmax: 0.000642
# Train Epoch: 27 [50000/60000 (83%)]	Losses softmax: 0.000585 log_softmax: 0.000713
# Train Epoch: 27 [60000/60000 (100%)]	Losses softmax: 0.000946 log_softmax: 0.000522
# Test set:
# softmax: Loss: 0.0729	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0781	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 28 [0/60000 (0%)]	Losses softmax: 0.001528 log_softmax: 0.000882
# Train Epoch: 28 [10000/60000 (17%)]	Losses softmax: 0.000956 log_softmax: 0.001050
# Train Epoch: 28 [20000/60000 (33%)]	Losses softmax: 0.000820 log_softmax: 0.000987
# Train Epoch: 28 [30000/60000 (50%)]	Losses softmax: 0.000867 log_softmax: 0.000545
# Train Epoch: 28 [40000/60000 (67%)]	Losses softmax: 0.000078 log_softmax: 0.000029
# Train Epoch: 28 [50000/60000 (83%)]	Losses softmax: 0.001146 log_softmax: 0.000655
# Train Epoch: 28 [60000/60000 (100%)]	Losses softmax: 0.000365 log_softmax: 0.000612
# Test set:
# softmax: Loss: 0.0730	Accuracy: 9809.0/10000 (98%)
# log_softmax: Loss: 0.0783	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 29 [0/60000 (0%)]	Losses softmax: 0.001234 log_softmax: 0.000841
# Train Epoch: 29 [10000/60000 (17%)]	Losses softmax: 0.000348 log_softmax: 0.000472
# Train Epoch: 29 [20000/60000 (33%)]	Losses softmax: 0.000690 log_softmax: 0.000661
# Train Epoch: 29 [30000/60000 (50%)]	Losses softmax: 0.000225 log_softmax: 0.000646
# Train Epoch: 29 [40000/60000 (67%)]	Losses softmax: 0.000446 log_softmax: 0.000496
# Train Epoch: 29 [50000/60000 (83%)]	Losses softmax: 0.000593 log_softmax: 0.000555
# Train Epoch: 29 [60000/60000 (100%)]	Losses softmax: 0.000288 log_softmax: 0.000342
# Test set:
# softmax: Loss: 0.0729	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0784	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 30 [0/60000 (0%)]	Losses softmax: 0.000908 log_softmax: 0.000828
# Train Epoch: 30 [10000/60000 (17%)]	Losses softmax: 0.000525 log_softmax: 0.000485
# Train Epoch: 30 [20000/60000 (33%)]	Losses softmax: 0.001326 log_softmax: 0.002345
# Train Epoch: 30 [30000/60000 (50%)]	Losses softmax: 0.000568 log_softmax: 0.000333
# Train Epoch: 30 [40000/60000 (67%)]	Losses softmax: 0.001221 log_softmax: 0.001500
# Train Epoch: 30 [50000/60000 (83%)]	Losses softmax: 0.000780 log_softmax: 0.000602
# Train Epoch: 30 [60000/60000 (100%)]	Losses softmax: 0.000332 log_softmax: 0.000325
# Test set:
# softmax: Loss: 0.0734	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0787	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 31 [0/60000 (0%)]	Losses softmax: 0.000595 log_softmax: 0.000504
# Train Epoch: 31 [10000/60000 (17%)]	Losses softmax: 0.001139 log_softmax: 0.001203
# Train Epoch: 31 [20000/60000 (33%)]	Losses softmax: 0.000680 log_softmax: 0.000960
# Train Epoch: 31 [30000/60000 (50%)]	Losses softmax: 0.000398 log_softmax: 0.000781
# Train Epoch: 31 [40000/60000 (67%)]	Losses softmax: 0.001212 log_softmax: 0.000604
# Train Epoch: 31 [50000/60000 (83%)]	Losses softmax: 0.000249 log_softmax: 0.000214
# Train Epoch: 31 [60000/60000 (100%)]	Losses softmax: 0.000117 log_softmax: 0.000223
# Test set:
# softmax: Loss: 0.0728	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0786	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 32 [0/60000 (0%)]	Losses softmax: 0.000877 log_softmax: 0.000565
# Train Epoch: 32 [10000/60000 (17%)]	Losses softmax: 0.000711 log_softmax: 0.000916
# Train Epoch: 32 [20000/60000 (33%)]	Losses softmax: 0.000611 log_softmax: 0.000997
# Train Epoch: 32 [30000/60000 (50%)]	Losses softmax: 0.000367 log_softmax: 0.000917
# Train Epoch: 32 [40000/60000 (67%)]	Losses softmax: 0.000198 log_softmax: 0.000317
# Train Epoch: 32 [50000/60000 (83%)]	Losses softmax: 0.001218 log_softmax: 0.000794
# Train Epoch: 32 [60000/60000 (100%)]	Losses softmax: 0.000866 log_softmax: 0.000854
# Test set:
# softmax: Loss: 0.0733	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0789	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 33 [0/60000 (0%)]	Losses softmax: 0.000797 log_softmax: 0.000541
# Train Epoch: 33 [10000/60000 (17%)]	Losses softmax: 0.000752 log_softmax: 0.000756
# Train Epoch: 33 [20000/60000 (33%)]	Losses softmax: 0.000879 log_softmax: 0.000889
# Train Epoch: 33 [30000/60000 (50%)]	Losses softmax: 0.000521 log_softmax: 0.000535
# Train Epoch: 33 [40000/60000 (67%)]	Losses softmax: 0.001155 log_softmax: 0.001152
# Train Epoch: 33 [50000/60000 (83%)]	Losses softmax: 0.000733 log_softmax: 0.000934
# Train Epoch: 33 [60000/60000 (100%)]	Losses softmax: 0.000528 log_softmax: 0.000278
# Test set:
# softmax: Loss: 0.0738	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0794	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 34 [0/60000 (0%)]	Losses softmax: 0.000524 log_softmax: 0.000456
# Train Epoch: 34 [10000/60000 (17%)]	Losses softmax: 0.000222 log_softmax: 0.000234
# Train Epoch: 34 [20000/60000 (33%)]	Losses softmax: 0.001347 log_softmax: 0.001256
# Train Epoch: 34 [30000/60000 (50%)]	Losses softmax: 0.000427 log_softmax: 0.000281
# Train Epoch: 34 [40000/60000 (67%)]	Losses softmax: 0.000995 log_softmax: 0.000623
# Train Epoch: 34 [50000/60000 (83%)]	Losses softmax: 0.000868 log_softmax: 0.000394
# Train Epoch: 34 [60000/60000 (100%)]	Losses softmax: 0.001241 log_softmax: 0.000729
# Test set:
# softmax: Loss: 0.0739	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0797	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 35 [0/60000 (0%)]	Losses softmax: 0.000996 log_softmax: 0.000845
# Train Epoch: 35 [10000/60000 (17%)]	Losses softmax: 0.000741 log_softmax: 0.000722
# Train Epoch: 35 [20000/60000 (33%)]	Losses softmax: 0.000453 log_softmax: 0.000697
# Train Epoch: 35 [30000/60000 (50%)]	Losses softmax: 0.001030 log_softmax: 0.001229
# Train Epoch: 35 [40000/60000 (67%)]	Losses softmax: 0.001130 log_softmax: 0.000899
# Train Epoch: 35 [50000/60000 (83%)]	Losses softmax: 0.001251 log_softmax: 0.000670
# Train Epoch: 35 [60000/60000 (100%)]	Losses softmax: 0.000061 log_softmax: 0.000103
# Test set:
# softmax: Loss: 0.0742	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0799	Accuracy: 9785.0/10000 (98%)
#
# Train Epoch: 36 [0/60000 (0%)]	Losses softmax: 0.000901 log_softmax: 0.000821
# Train Epoch: 36 [10000/60000 (17%)]	Losses softmax: 0.000753 log_softmax: 0.000305
# Train Epoch: 36 [20000/60000 (33%)]	Losses softmax: 0.000208 log_softmax: 0.000280
# Train Epoch: 36 [30000/60000 (50%)]	Losses softmax: 0.000556 log_softmax: 0.000373
# Train Epoch: 36 [40000/60000 (67%)]	Losses softmax: 0.000329 log_softmax: 0.000394
# Train Epoch: 36 [50000/60000 (83%)]	Losses softmax: 0.000697 log_softmax: 0.000564
# Train Epoch: 36 [60000/60000 (100%)]	Losses softmax: 0.001925 log_softmax: 0.001950
# Test set:
# softmax: Loss: 0.0743	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0796	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 37 [0/60000 (0%)]	Losses softmax: 0.000927 log_softmax: 0.001278
# Train Epoch: 37 [10000/60000 (17%)]	Losses softmax: 0.000884 log_softmax: 0.001226
# Train Epoch: 37 [20000/60000 (33%)]	Losses softmax: 0.000170 log_softmax: 0.000470
# Train Epoch: 37 [30000/60000 (50%)]	Losses softmax: 0.000191 log_softmax: 0.000225
# Train Epoch: 37 [40000/60000 (67%)]	Losses softmax: 0.000950 log_softmax: 0.001021
# Train Epoch: 37 [50000/60000 (83%)]	Losses softmax: 0.000169 log_softmax: 0.000601
# Train Epoch: 37 [60000/60000 (100%)]	Losses softmax: 0.000560 log_softmax: 0.000569
# Test set:
# softmax: Loss: 0.0743	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0801	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 38 [0/60000 (0%)]	Losses softmax: 0.000307 log_softmax: 0.000531
# Train Epoch: 38 [10000/60000 (17%)]	Losses softmax: 0.000289 log_softmax: 0.000506
# Train Epoch: 38 [20000/60000 (33%)]	Losses softmax: 0.000727 log_softmax: 0.001049
# Train Epoch: 38 [30000/60000 (50%)]	Losses softmax: 0.000643 log_softmax: 0.000964
# Train Epoch: 38 [40000/60000 (67%)]	Losses softmax: 0.000264 log_softmax: 0.000655
# Train Epoch: 38 [50000/60000 (83%)]	Losses softmax: 0.000387 log_softmax: 0.000692
# Train Epoch: 38 [60000/60000 (100%)]	Losses softmax: 0.000946 log_softmax: 0.000522
# Test set:
# softmax: Loss: 0.0748	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0804	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 39 [0/60000 (0%)]	Losses softmax: 0.000266 log_softmax: 0.000258
# Train Epoch: 39 [10000/60000 (17%)]	Losses softmax: 0.000297 log_softmax: 0.000210
# Train Epoch: 39 [20000/60000 (33%)]	Losses softmax: 0.000257 log_softmax: 0.000245
# Train Epoch: 39 [30000/60000 (50%)]	Losses softmax: 0.000416 log_softmax: 0.000320
# Train Epoch: 39 [40000/60000 (67%)]	Losses softmax: 0.000740 log_softmax: 0.000463
# Train Epoch: 39 [50000/60000 (83%)]	Losses softmax: 0.001128 log_softmax: 0.000815
# Train Epoch: 39 [60000/60000 (100%)]	Losses softmax: 0.000305 log_softmax: 0.000055
# Test set:
# softmax: Loss: 0.0753	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0808	Accuracy: 9787.0/10000 (98%)
#
# Train Epoch: 40 [0/60000 (0%)]	Losses softmax: 0.000653 log_softmax: 0.000822
# Train Epoch: 40 [10000/60000 (17%)]	Losses softmax: 0.000552 log_softmax: 0.000807
# Train Epoch: 40 [20000/60000 (33%)]	Losses softmax: 0.000802 log_softmax: 0.000508
# Train Epoch: 40 [30000/60000 (50%)]	Losses softmax: 0.000750 log_softmax: 0.000468
# Train Epoch: 40 [40000/60000 (67%)]	Losses softmax: 0.000147 log_softmax: 0.000156
# Train Epoch: 40 [50000/60000 (83%)]	Losses softmax: 0.000644 log_softmax: 0.000474
# Train Epoch: 40 [60000/60000 (100%)]	Losses softmax: 0.000432 log_softmax: 0.000773
# Test set:
# softmax: Loss: 0.0752	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0808	Accuracy: 9785.0/10000 (98%)
#
# Train Epoch: 41 [0/60000 (0%)]	Losses softmax: 0.000889 log_softmax: 0.000674
# Train Epoch: 41 [10000/60000 (17%)]	Losses softmax: 0.000530 log_softmax: 0.000483
# Train Epoch: 41 [20000/60000 (33%)]	Losses softmax: 0.000800 log_softmax: 0.000292
# Train Epoch: 41 [30000/60000 (50%)]	Losses softmax: 0.000428 log_softmax: 0.000601
# Train Epoch: 41 [40000/60000 (67%)]	Losses softmax: 0.000094 log_softmax: 0.000078
# Train Epoch: 41 [50000/60000 (83%)]	Losses softmax: 0.000536 log_softmax: 0.000509
# Train Epoch: 41 [60000/60000 (100%)]	Losses softmax: 0.000202 log_softmax: 0.000190
# Test set:
# softmax: Loss: 0.0753	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0810	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 42 [0/60000 (0%)]	Losses softmax: 0.000459 log_softmax: 0.000164
# Train Epoch: 42 [10000/60000 (17%)]	Losses softmax: 0.000655 log_softmax: 0.000797
# Train Epoch: 42 [20000/60000 (33%)]	Losses softmax: 0.000232 log_softmax: 0.000225
# Train Epoch: 42 [30000/60000 (50%)]	Losses softmax: 0.000328 log_softmax: 0.000587
# Train Epoch: 42 [40000/60000 (67%)]	Losses softmax: 0.000333 log_softmax: 0.000292
# Train Epoch: 42 [50000/60000 (83%)]	Losses softmax: 0.000423 log_softmax: 0.000387
# Train Epoch: 42 [60000/60000 (100%)]	Losses softmax: 0.000716 log_softmax: 0.000766
# Test set:
# softmax: Loss: 0.0755	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0812	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 43 [0/60000 (0%)]	Losses softmax: 0.000227 log_softmax: 0.000194
# Train Epoch: 43 [10000/60000 (17%)]	Losses softmax: 0.000659 log_softmax: 0.001129
# Train Epoch: 43 [20000/60000 (33%)]	Losses softmax: 0.000744 log_softmax: 0.000591
# Train Epoch: 43 [30000/60000 (50%)]	Losses softmax: 0.000236 log_softmax: 0.000460
# Train Epoch: 43 [40000/60000 (67%)]	Losses softmax: 0.000526 log_softmax: 0.000207
# Train Epoch: 43 [50000/60000 (83%)]	Losses softmax: 0.000521 log_softmax: 0.000379
# Train Epoch: 43 [60000/60000 (100%)]	Losses softmax: 0.000893 log_softmax: 0.000689
# Test set:
# softmax: Loss: 0.0757	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0814	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 44 [0/60000 (0%)]	Losses softmax: 0.000483 log_softmax: 0.000737
# Train Epoch: 44 [10000/60000 (17%)]	Losses softmax: 0.000239 log_softmax: 0.000100
# Train Epoch: 44 [20000/60000 (33%)]	Losses softmax: 0.000538 log_softmax: 0.000328
# Train Epoch: 44 [30000/60000 (50%)]	Losses softmax: 0.000448 log_softmax: 0.000658
# Train Epoch: 44 [40000/60000 (67%)]	Losses softmax: 0.000160 log_softmax: 0.000143
# Train Epoch: 44 [50000/60000 (83%)]	Losses softmax: 0.000498 log_softmax: 0.000825
# Train Epoch: 44 [60000/60000 (100%)]	Losses softmax: 0.000508 log_softmax: 0.000245
# Test set:
# softmax: Loss: 0.0756	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0812	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 45 [0/60000 (0%)]	Losses softmax: 0.000332 log_softmax: 0.000454
# Train Epoch: 45 [10000/60000 (17%)]	Losses softmax: 0.000805 log_softmax: 0.000622
# Train Epoch: 45 [20000/60000 (33%)]	Losses softmax: 0.000483 log_softmax: 0.000518
# Train Epoch: 45 [30000/60000 (50%)]	Losses softmax: 0.000449 log_softmax: 0.000541
# Train Epoch: 45 [40000/60000 (67%)]	Losses softmax: 0.000426 log_softmax: 0.000477
# Train Epoch: 45 [50000/60000 (83%)]	Losses softmax: 0.000597 log_softmax: 0.000419
# Train Epoch: 45 [60000/60000 (100%)]	Losses softmax: 0.000450 log_softmax: 0.000996
# Test set:
# softmax: Loss: 0.0758	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0817	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 46 [0/60000 (0%)]	Losses softmax: 0.000064 log_softmax: 0.000079
# Train Epoch: 46 [10000/60000 (17%)]	Losses softmax: 0.000299 log_softmax: 0.000425
# Train Epoch: 46 [20000/60000 (33%)]	Losses softmax: 0.000868 log_softmax: 0.000930
# Train Epoch: 46 [30000/60000 (50%)]	Losses softmax: 0.000255 log_softmax: 0.000252
# Train Epoch: 46 [40000/60000 (67%)]	Losses softmax: 0.000747 log_softmax: 0.000547
# Train Epoch: 46 [50000/60000 (83%)]	Losses softmax: 0.000160 log_softmax: 0.000187
# Train Epoch: 46 [60000/60000 (100%)]	Losses softmax: 0.000328 log_softmax: 0.000170
# Test set:
# softmax: Loss: 0.0762	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0819	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 47 [0/60000 (0%)]	Losses softmax: 0.000664 log_softmax: 0.000445
# Train Epoch: 47 [10000/60000 (17%)]	Losses softmax: 0.000642 log_softmax: 0.000798
# Train Epoch: 47 [20000/60000 (33%)]	Losses softmax: 0.000498 log_softmax: 0.000398
# Train Epoch: 47 [30000/60000 (50%)]	Losses softmax: 0.000193 log_softmax: 0.000320
# Train Epoch: 47 [40000/60000 (67%)]	Losses softmax: 0.000379 log_softmax: 0.000420
# Train Epoch: 47 [50000/60000 (83%)]	Losses softmax: 0.000674 log_softmax: 0.000550
# Train Epoch: 47 [60000/60000 (100%)]	Losses softmax: 0.000600 log_softmax: 0.000846
# Test set:
# softmax: Loss: 0.0763	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0821	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 48 [0/60000 (0%)]	Losses softmax: 0.000759 log_softmax: 0.000687
# Train Epoch: 48 [10000/60000 (17%)]	Losses softmax: 0.001001 log_softmax: 0.000651
# Train Epoch: 48 [20000/60000 (33%)]	Losses softmax: 0.000278 log_softmax: 0.000244
# Train Epoch: 48 [30000/60000 (50%)]	Losses softmax: 0.001387 log_softmax: 0.001693
# Train Epoch: 48 [40000/60000 (67%)]	Losses softmax: 0.001763 log_softmax: 0.001438
# Train Epoch: 48 [50000/60000 (83%)]	Losses softmax: 0.000411 log_softmax: 0.000308
# Train Epoch: 48 [60000/60000 (100%)]	Losses softmax: 0.000160 log_softmax: 0.000206
# Test set:
# softmax: Loss: 0.0766	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0824	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 49 [0/60000 (0%)]	Losses softmax: 0.000223 log_softmax: 0.000135
# Train Epoch: 49 [10000/60000 (17%)]	Losses softmax: 0.001340 log_softmax: 0.000640
# Train Epoch: 49 [20000/60000 (33%)]	Losses softmax: 0.000712 log_softmax: 0.000452
# Train Epoch: 49 [30000/60000 (50%)]	Losses softmax: 0.000215 log_softmax: 0.000086
# Train Epoch: 49 [40000/60000 (67%)]	Losses softmax: 0.000328 log_softmax: 0.000164
# Train Epoch: 49 [50000/60000 (83%)]	Losses softmax: 0.000920 log_softmax: 0.000774
# Train Epoch: 49 [60000/60000 (100%)]	Losses softmax: 0.000225 log_softmax: 0.000318
# Test set:
# softmax: Loss: 0.0767	Accuracy: 9801.0/10000 (98%)
# log_softmax: Loss: 0.0824	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 50 [0/60000 (0%)]	Losses softmax: 0.000315 log_softmax: 0.000188
# Train Epoch: 50 [10000/60000 (17%)]	Losses softmax: 0.000537 log_softmax: 0.000295
# Train Epoch: 50 [20000/60000 (33%)]	Losses softmax: 0.000221 log_softmax: 0.000258
# Train Epoch: 50 [30000/60000 (50%)]	Losses softmax: 0.000465 log_softmax: 0.000248
# Train Epoch: 50 [40000/60000 (67%)]	Losses softmax: 0.000536 log_softmax: 0.000721
# Train Epoch: 50 [50000/60000 (83%)]	Losses softmax: 0.000698 log_softmax: 0.000743
# Train Epoch: 50 [60000/60000 (100%)]	Losses softmax: 0.000248 log_softmax: 0.000157
# Test set:
# softmax: Loss: 0.0772	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0828	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 51 [0/60000 (0%)]	Losses softmax: 0.000472 log_softmax: 0.000424
# Train Epoch: 51 [10000/60000 (17%)]	Losses softmax: 0.000705 log_softmax: 0.000382
# Train Epoch: 51 [20000/60000 (33%)]	Losses softmax: 0.000607 log_softmax: 0.000569
# Train Epoch: 51 [30000/60000 (50%)]	Losses softmax: 0.000966 log_softmax: 0.000669
# Train Epoch: 51 [40000/60000 (67%)]	Losses softmax: 0.000671 log_softmax: 0.000192
# Train Epoch: 51 [50000/60000 (83%)]	Losses softmax: 0.000263 log_softmax: 0.000343
# Train Epoch: 51 [60000/60000 (100%)]	Losses softmax: 0.000459 log_softmax: 0.000454
# Test set:
# softmax: Loss: 0.0767	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0828	Accuracy: 9788.0/10000 (98%)
#
# Train Epoch: 52 [0/60000 (0%)]	Losses softmax: 0.000220 log_softmax: 0.000175
# Train Epoch: 52 [10000/60000 (17%)]	Losses softmax: 0.000362 log_softmax: 0.000409
# Train Epoch: 52 [20000/60000 (33%)]	Losses softmax: 0.000397 log_softmax: 0.000412
# Train Epoch: 52 [30000/60000 (50%)]	Losses softmax: 0.000290 log_softmax: 0.000278
# Train Epoch: 52 [40000/60000 (67%)]	Losses softmax: 0.000116 log_softmax: 0.000373
# Train Epoch: 52 [50000/60000 (83%)]	Losses softmax: 0.000599 log_softmax: 0.001305
# Train Epoch: 52 [60000/60000 (100%)]	Losses softmax: 0.000253 log_softmax: 0.000225
# Test set:
# softmax: Loss: 0.0771	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0831	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 53 [0/60000 (0%)]	Losses softmax: 0.000406 log_softmax: 0.000332
# Train Epoch: 53 [10000/60000 (17%)]	Losses softmax: 0.000474 log_softmax: 0.000148
# Train Epoch: 53 [20000/60000 (33%)]	Losses softmax: 0.000304 log_softmax: 0.000253
# Train Epoch: 53 [30000/60000 (50%)]	Losses softmax: 0.000761 log_softmax: 0.000667
# Train Epoch: 53 [40000/60000 (67%)]	Losses softmax: 0.000241 log_softmax: 0.000479
# Train Epoch: 53 [50000/60000 (83%)]	Losses softmax: 0.000475 log_softmax: 0.000545
# Train Epoch: 53 [60000/60000 (100%)]	Losses softmax: 0.000386 log_softmax: 0.000075
# Test set:
# softmax: Loss: 0.0771	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0829	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 54 [0/60000 (0%)]	Losses softmax: 0.000178 log_softmax: 0.000185
# Train Epoch: 54 [10000/60000 (17%)]	Losses softmax: 0.000313 log_softmax: 0.000379
# Train Epoch: 54 [20000/60000 (33%)]	Losses softmax: 0.000412 log_softmax: 0.000186
# Train Epoch: 54 [30000/60000 (50%)]	Losses softmax: 0.000533 log_softmax: 0.000421
# Train Epoch: 54 [40000/60000 (67%)]	Losses softmax: 0.000168 log_softmax: 0.000188
# Train Epoch: 54 [50000/60000 (83%)]	Losses softmax: 0.000495 log_softmax: 0.000446
# Train Epoch: 54 [60000/60000 (100%)]	Losses softmax: 0.000339 log_softmax: 0.000345
# Test set:
# softmax: Loss: 0.0774	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0832	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 55 [0/60000 (0%)]	Losses softmax: 0.000550 log_softmax: 0.000326
# Train Epoch: 55 [10000/60000 (17%)]	Losses softmax: 0.000378 log_softmax: 0.000295
# Train Epoch: 55 [20000/60000 (33%)]	Losses softmax: 0.000083 log_softmax: 0.000113
# Train Epoch: 55 [30000/60000 (50%)]	Losses softmax: 0.000148 log_softmax: 0.000321
# Train Epoch: 55 [40000/60000 (67%)]	Losses softmax: 0.000265 log_softmax: 0.000252
# Train Epoch: 55 [50000/60000 (83%)]	Losses softmax: 0.000302 log_softmax: 0.000349
# Train Epoch: 55 [60000/60000 (100%)]	Losses softmax: 0.000355 log_softmax: 0.000531
# Test set:
# softmax: Loss: 0.0770	Accuracy: 9807.0/10000 (98%)
# log_softmax: Loss: 0.0831	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 56 [0/60000 (0%)]	Losses softmax: 0.000375 log_softmax: 0.000178
# Train Epoch: 56 [10000/60000 (17%)]	Losses softmax: 0.000551 log_softmax: 0.000246
# Train Epoch: 56 [20000/60000 (33%)]	Losses softmax: 0.000097 log_softmax: 0.000137
# Train Epoch: 56 [30000/60000 (50%)]	Losses softmax: 0.000301 log_softmax: 0.000575
# Train Epoch: 56 [40000/60000 (67%)]	Losses softmax: 0.000105 log_softmax: 0.000301
# Train Epoch: 56 [50000/60000 (83%)]	Losses softmax: 0.000619 log_softmax: 0.000388
# Train Epoch: 56 [60000/60000 (100%)]	Losses softmax: 0.000372 log_softmax: 0.000361
# Test set:
# softmax: Loss: 0.0775	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0834	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 57 [0/60000 (0%)]	Losses softmax: 0.000577 log_softmax: 0.000727
# Train Epoch: 57 [10000/60000 (17%)]	Losses softmax: 0.000267 log_softmax: 0.000181
# Train Epoch: 57 [20000/60000 (33%)]	Losses softmax: 0.000174 log_softmax: 0.000081
# Train Epoch: 57 [30000/60000 (50%)]	Losses softmax: 0.000202 log_softmax: 0.000298
# Train Epoch: 57 [40000/60000 (67%)]	Losses softmax: 0.000216 log_softmax: 0.000313
# Train Epoch: 57 [50000/60000 (83%)]	Losses softmax: 0.000174 log_softmax: 0.000322
# Train Epoch: 57 [60000/60000 (100%)]	Losses softmax: 0.000286 log_softmax: 0.000265
# Test set:
# softmax: Loss: 0.0779	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0836	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 58 [0/60000 (0%)]	Losses softmax: 0.000899 log_softmax: 0.000417
# Train Epoch: 58 [10000/60000 (17%)]	Losses softmax: 0.001390 log_softmax: 0.001098
# Train Epoch: 58 [20000/60000 (33%)]	Losses softmax: 0.000120 log_softmax: 0.000048
# Train Epoch: 58 [30000/60000 (50%)]	Losses softmax: 0.000157 log_softmax: 0.000084
# Train Epoch: 58 [40000/60000 (67%)]	Losses softmax: 0.000205 log_softmax: 0.000187
# Train Epoch: 58 [50000/60000 (83%)]	Losses softmax: 0.000240 log_softmax: 0.000132
# Train Epoch: 58 [60000/60000 (100%)]	Losses softmax: 0.000983 log_softmax: 0.000930
# Test set:
# softmax: Loss: 0.0775	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0835	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 59 [0/60000 (0%)]	Losses softmax: 0.000161 log_softmax: 0.000108
# Train Epoch: 59 [10000/60000 (17%)]	Losses softmax: 0.000310 log_softmax: 0.000200
# Train Epoch: 59 [20000/60000 (33%)]	Losses softmax: 0.000162 log_softmax: 0.000164
# Train Epoch: 59 [30000/60000 (50%)]	Losses softmax: 0.000334 log_softmax: 0.000168
# Train Epoch: 59 [40000/60000 (67%)]	Losses softmax: 0.000772 log_softmax: 0.001159
# Train Epoch: 59 [50000/60000 (83%)]	Losses softmax: 0.000592 log_softmax: 0.000587
# Train Epoch: 59 [60000/60000 (100%)]	Losses softmax: 0.000311 log_softmax: 0.000420
# Test set:
# softmax: Loss: 0.0778	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0837	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 60 [0/60000 (0%)]	Losses softmax: 0.000346 log_softmax: 0.000321
# Train Epoch: 60 [10000/60000 (17%)]	Losses softmax: 0.000228 log_softmax: 0.000140
# Train Epoch: 60 [20000/60000 (33%)]	Losses softmax: 0.000181 log_softmax: 0.000120
# Train Epoch: 60 [30000/60000 (50%)]	Losses softmax: 0.000467 log_softmax: 0.000466
# Train Epoch: 60 [40000/60000 (67%)]	Losses softmax: 0.000606 log_softmax: 0.000376
# Train Epoch: 60 [50000/60000 (83%)]	Losses softmax: 0.000309 log_softmax: 0.000266
# Train Epoch: 60 [60000/60000 (100%)]	Losses softmax: 0.000448 log_softmax: 0.000414
# Test set:
# softmax: Loss: 0.0778	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0837	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 61 [0/60000 (0%)]	Losses softmax: 0.000422 log_softmax: 0.000667
# Train Epoch: 61 [10000/60000 (17%)]	Losses softmax: 0.000114 log_softmax: 0.000132
# Train Epoch: 61 [20000/60000 (33%)]	Losses softmax: 0.000640 log_softmax: 0.000871
# Train Epoch: 61 [30000/60000 (50%)]	Losses softmax: 0.000253 log_softmax: 0.000212
# Train Epoch: 61 [40000/60000 (67%)]	Losses softmax: 0.000345 log_softmax: 0.000463
# Train Epoch: 61 [50000/60000 (83%)]	Losses softmax: 0.000280 log_softmax: 0.000078
# Train Epoch: 61 [60000/60000 (100%)]	Losses softmax: 0.000145 log_softmax: 0.000160
# Test set:
# softmax: Loss: 0.0781	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0839	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 62 [0/60000 (0%)]	Losses softmax: 0.000291 log_softmax: 0.000188
# Train Epoch: 62 [10000/60000 (17%)]	Losses softmax: 0.000138 log_softmax: 0.000302
# Train Epoch: 62 [20000/60000 (33%)]	Losses softmax: 0.000443 log_softmax: 0.000436
# Train Epoch: 62 [30000/60000 (50%)]	Losses softmax: 0.000342 log_softmax: 0.000787
# Train Epoch: 62 [40000/60000 (67%)]	Losses softmax: 0.000095 log_softmax: 0.000108
# Train Epoch: 62 [50000/60000 (83%)]	Losses softmax: 0.000593 log_softmax: 0.000349
# Train Epoch: 62 [60000/60000 (100%)]	Losses softmax: 0.000708 log_softmax: 0.000474
# Test set:
# softmax: Loss: 0.0780	Accuracy: 9808.0/10000 (98%)
# log_softmax: Loss: 0.0839	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 63 [0/60000 (0%)]	Losses softmax: 0.000247 log_softmax: 0.000147
# Train Epoch: 63 [10000/60000 (17%)]	Losses softmax: 0.000137 log_softmax: 0.000232
# Train Epoch: 63 [20000/60000 (33%)]	Losses softmax: 0.000273 log_softmax: 0.000302
# Train Epoch: 63 [30000/60000 (50%)]	Losses softmax: 0.000342 log_softmax: 0.000278
# Train Epoch: 63 [40000/60000 (67%)]	Losses softmax: 0.000269 log_softmax: 0.000378
# Train Epoch: 63 [50000/60000 (83%)]	Losses softmax: 0.000253 log_softmax: 0.000158
# Train Epoch: 63 [60000/60000 (100%)]	Losses softmax: 0.000597 log_softmax: 0.000658
# Test set:
# softmax: Loss: 0.0784	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0843	Accuracy: 9789.0/10000 (98%)
#
# Train Epoch: 64 [0/60000 (0%)]	Losses softmax: 0.000559 log_softmax: 0.000579
# Train Epoch: 64 [10000/60000 (17%)]	Losses softmax: 0.000259 log_softmax: 0.000318
# Train Epoch: 64 [20000/60000 (33%)]	Losses softmax: 0.000418 log_softmax: 0.000631
# Train Epoch: 64 [30000/60000 (50%)]	Losses softmax: 0.000547 log_softmax: 0.000559
# Train Epoch: 64 [40000/60000 (67%)]	Losses softmax: 0.000507 log_softmax: 0.000435
# Train Epoch: 64 [50000/60000 (83%)]	Losses softmax: 0.000570 log_softmax: 0.000524
# Train Epoch: 64 [60000/60000 (100%)]	Losses softmax: 0.000699 log_softmax: 0.000807
# Test set:
# softmax: Loss: 0.0785	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0841	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 65 [0/60000 (0%)]	Losses softmax: 0.000290 log_softmax: 0.000232
# Train Epoch: 65 [10000/60000 (17%)]	Losses softmax: 0.000708 log_softmax: 0.000582
# Train Epoch: 65 [20000/60000 (33%)]	Losses softmax: 0.000125 log_softmax: 0.000235
# Train Epoch: 65 [30000/60000 (50%)]	Losses softmax: 0.000115 log_softmax: 0.000134
# Train Epoch: 65 [40000/60000 (67%)]	Losses softmax: 0.000219 log_softmax: 0.000127
# Train Epoch: 65 [50000/60000 (83%)]	Losses softmax: 0.000447 log_softmax: 0.000500
# Train Epoch: 65 [60000/60000 (100%)]	Losses softmax: 0.000429 log_softmax: 0.000278
# Test set:
# softmax: Loss: 0.0785	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0843	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 66 [0/60000 (0%)]	Losses softmax: 0.000613 log_softmax: 0.000398
# Train Epoch: 66 [10000/60000 (17%)]	Losses softmax: 0.000374 log_softmax: 0.000394
# Train Epoch: 66 [20000/60000 (33%)]	Losses softmax: 0.000415 log_softmax: 0.000480
# Train Epoch: 66 [30000/60000 (50%)]	Losses softmax: 0.000108 log_softmax: 0.000097
# Train Epoch: 66 [40000/60000 (67%)]	Losses softmax: 0.000302 log_softmax: 0.000143
# Train Epoch: 66 [50000/60000 (83%)]	Losses softmax: 0.000520 log_softmax: 0.000289
# Train Epoch: 66 [60000/60000 (100%)]	Losses softmax: 0.000281 log_softmax: 0.000222
# Test set:
# softmax: Loss: 0.0786	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0846	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 67 [0/60000 (0%)]	Losses softmax: 0.000558 log_softmax: 0.000276
# Train Epoch: 67 [10000/60000 (17%)]	Losses softmax: 0.000210 log_softmax: 0.000200
# Train Epoch: 67 [20000/60000 (33%)]	Losses softmax: 0.000433 log_softmax: 0.000569
# Train Epoch: 67 [30000/60000 (50%)]	Losses softmax: 0.000081 log_softmax: 0.000125
# Train Epoch: 67 [40000/60000 (67%)]	Losses softmax: 0.000171 log_softmax: 0.000109
# Train Epoch: 67 [50000/60000 (83%)]	Losses softmax: 0.000625 log_softmax: 0.000601
# Train Epoch: 67 [60000/60000 (100%)]	Losses softmax: 0.000212 log_softmax: 0.000210
# Test set:
# softmax: Loss: 0.0787	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0846	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 68 [0/60000 (0%)]	Losses softmax: 0.000166 log_softmax: 0.000228
# Train Epoch: 68 [10000/60000 (17%)]	Losses softmax: 0.000516 log_softmax: 0.000358
# Train Epoch: 68 [20000/60000 (33%)]	Losses softmax: 0.000509 log_softmax: 0.000494
# Train Epoch: 68 [30000/60000 (50%)]	Losses softmax: 0.000345 log_softmax: 0.000367
# Train Epoch: 68 [40000/60000 (67%)]	Losses softmax: 0.000305 log_softmax: 0.000347
# Train Epoch: 68 [50000/60000 (83%)]	Losses softmax: 0.000510 log_softmax: 0.000321
# Train Epoch: 68 [60000/60000 (100%)]	Losses softmax: 0.000589 log_softmax: 0.000254
# Test set:
# softmax: Loss: 0.0789	Accuracy: 9801.0/10000 (98%)
# log_softmax: Loss: 0.0847	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 69 [0/60000 (0%)]	Losses softmax: 0.000241 log_softmax: 0.000442
# Train Epoch: 69 [10000/60000 (17%)]	Losses softmax: 0.000707 log_softmax: 0.000643
# Train Epoch: 69 [20000/60000 (33%)]	Losses softmax: 0.000215 log_softmax: 0.000224
# Train Epoch: 69 [30000/60000 (50%)]	Losses softmax: 0.000534 log_softmax: 0.000585
# Train Epoch: 69 [40000/60000 (67%)]	Losses softmax: 0.000218 log_softmax: 0.000459
# Train Epoch: 69 [50000/60000 (83%)]	Losses softmax: 0.000255 log_softmax: 0.000257
# Train Epoch: 69 [60000/60000 (100%)]	Losses softmax: 0.000313 log_softmax: 0.000288
# Test set:
# softmax: Loss: 0.0791	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0851	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 70 [0/60000 (0%)]	Losses softmax: 0.000489 log_softmax: 0.000494
# Train Epoch: 70 [10000/60000 (17%)]	Losses softmax: 0.000350 log_softmax: 0.000248
# ...
#
# Train Epoch: 78 [0/60000 (0%)]	Losses softmax: 0.000161 log_softmax: 0.000157
# Train Epoch: 78 [10000/60000 (17%)]	Losses softmax: 0.000127 log_softmax: 0.000106
# Train Epoch: 78 [20000/60000 (33%)]	Losses softmax: 0.000136 log_softmax: 0.000141
# Train Epoch: 78 [30000/60000 (50%)]	Losses softmax: 0.000450 log_softmax: 0.000688
# Train Epoch: 78 [40000/60000 (67%)]	Losses softmax: 0.000133 log_softmax: 0.000060
# Train Epoch: 78 [50000/60000 (83%)]	Losses softmax: 0.000253 log_softmax: 0.000305
# Train Epoch: 78 [60000/60000 (100%)]	Losses softmax: 0.000159 log_softmax: 0.000293
# Test set:
# softmax: Loss: 0.0799	Accuracy: 9801.0/10000 (98%)
# log_softmax: Loss: 0.0858	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 79 [0/60000 (0%)]	Losses softmax: 0.000042 log_softmax: 0.000020
# Train Epoch: 79 [10000/60000 (17%)]	Losses softmax: 0.000261 log_softmax: 0.000186
# Train Epoch: 79 [20000/60000 (33%)]	Losses softmax: 0.000363 log_softmax: 0.000361
# Train Epoch: 79 [30000/60000 (50%)]	Losses softmax: 0.000373 log_softmax: 0.000327
# Train Epoch: 79 [40000/60000 (67%)]	Losses softmax: 0.000200 log_softmax: 0.000165
# Train Epoch: 79 [50000/60000 (83%)]	Losses softmax: 0.000352 log_softmax: 0.000370
# Train Epoch: 79 [60000/60000 (100%)]	Losses softmax: 0.000169 log_softmax: 0.000381
# Test set:
# softmax: Loss: 0.0798	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0859	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 80 [0/60000 (0%)]	Losses softmax: 0.000298 log_softmax: 0.000192
# Train Epoch: 80 [10000/60000 (17%)]	Losses softmax: 0.000261 log_softmax: 0.000204
# Train Epoch: 80 [20000/60000 (33%)]	Losses softmax: 0.000320 log_softmax: 0.000470
# Train Epoch: 80 [30000/60000 (50%)]	Losses softmax: 0.000229 log_softmax: 0.000247
# Train Epoch: 80 [40000/60000 (67%)]	Losses softmax: 0.000210 log_softmax: 0.000094
# Train Epoch: 80 [50000/60000 (83%)]	Losses softmax: 0.000195 log_softmax: 0.000037
# Train Epoch: 80 [60000/60000 (100%)]	Losses softmax: 0.000340 log_softmax: 0.000283
# Test set:
# softmax: Loss: 0.0799	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0859	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 81 [0/60000 (0%)]	Losses softmax: 0.000239 log_softmax: 0.000272
# Train Epoch: 81 [10000/60000 (17%)]	Losses softmax: 0.000115 log_softmax: 0.000087
# Train Epoch: 81 [20000/60000 (33%)]	Losses softmax: 0.000227 log_softmax: 0.000182
# Train Epoch: 81 [30000/60000 (50%)]	Losses softmax: 0.000279 log_softmax: 0.000232
# Train Epoch: 81 [40000/60000 (67%)]	Losses softmax: 0.000272 log_softmax: 0.000245
# Train Epoch: 81 [50000/60000 (83%)]	Losses softmax: 0.000269 log_softmax: 0.000288
# Train Epoch: 81 [60000/60000 (100%)]	Losses softmax: 0.000069 log_softmax: 0.000101
# Test set:
# softmax: Loss: 0.0801	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0859	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 82 [0/60000 (0%)]	Losses softmax: 0.000298 log_softmax: 0.000124
# Train Epoch: 82 [10000/60000 (17%)]	Losses softmax: 0.000075 log_softmax: 0.000115
# Train Epoch: 82 [20000/60000 (33%)]	Losses softmax: 0.000377 log_softmax: 0.000443
# Train Epoch: 82 [30000/60000 (50%)]	Losses softmax: 0.000040 log_softmax: 0.000052
# Train Epoch: 82 [40000/60000 (67%)]	Losses softmax: 0.000240 log_softmax: 0.000263
# Train Epoch: 82 [50000/60000 (83%)]	Losses softmax: 0.000112 log_softmax: 0.000099
# Train Epoch: 82 [60000/60000 (100%)]	Losses softmax: 0.000272 log_softmax: 0.000283
# Test set:
# softmax: Loss: 0.0802	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0862	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 83 [0/60000 (0%)]	Losses softmax: 0.000181 log_softmax: 0.000014
# Train Epoch: 83 [10000/60000 (17%)]	Losses softmax: 0.000388 log_softmax: 0.000234
# Train Epoch: 83 [20000/60000 (33%)]	Losses softmax: 0.000244 log_softmax: 0.000605
# Train Epoch: 83 [30000/60000 (50%)]	Losses softmax: 0.000068 log_softmax: 0.000096
# Train Epoch: 83 [40000/60000 (67%)]	Losses softmax: 0.000392 log_softmax: 0.000320
# Train Epoch: 83 [50000/60000 (83%)]	Losses softmax: 0.000106 log_softmax: 0.000104
# Train Epoch: 83 [60000/60000 (100%)]	Losses softmax: 0.000488 log_softmax: 0.000362
# Test set:
# softmax: Loss: 0.0802	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0863	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 84 [0/60000 (0%)]	Losses softmax: 0.000296 log_softmax: 0.000190
# Train Epoch: 84 [10000/60000 (17%)]	Losses softmax: 0.000052 log_softmax: 0.000081
# Train Epoch: 84 [20000/60000 (33%)]	Losses softmax: 0.000113 log_softmax: 0.000099
# Train Epoch: 84 [30000/60000 (50%)]	Losses softmax: 0.000229 log_softmax: 0.000223
# Train Epoch: 84 [40000/60000 (67%)]	Losses softmax: 0.000217 log_softmax: 0.000173
# Train Epoch: 84 [50000/60000 (83%)]	Losses softmax: 0.000293 log_softmax: 0.000295
# Train Epoch: 84 [60000/60000 (100%)]	Losses softmax: 0.000155 log_softmax: 0.000157
# Test set:
# softmax: Loss: 0.0804	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0864	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 85 [0/60000 (0%)]	Losses softmax: 0.000214 log_softmax: 0.000209
# Train Epoch: 85 [10000/60000 (17%)]	Losses softmax: 0.000130 log_softmax: 0.000143
# Train Epoch: 85 [20000/60000 (33%)]	Losses softmax: 0.000109 log_softmax: 0.000158
# Train Epoch: 85 [30000/60000 (50%)]	Losses softmax: 0.000703 log_softmax: 0.000607
# Train Epoch: 85 [40000/60000 (67%)]	Losses softmax: 0.000059 log_softmax: 0.000058
# Train Epoch: 85 [50000/60000 (83%)]	Losses softmax: 0.000232 log_softmax: 0.000170
# Train Epoch: 85 [60000/60000 (100%)]	Losses softmax: 0.000253 log_softmax: 0.000089
# Test set:
# softmax: Loss: 0.0804	Accuracy: 9806.0/10000 (98%)
# log_softmax: Loss: 0.0864	Accuracy: 9795.0/10000 (98%)
#
# Train Epoch: 86 [0/60000 (0%)]	Losses softmax: 0.000292 log_softmax: 0.000240
# Train Epoch: 86 [10000/60000 (17%)]	Losses softmax: 0.000226 log_softmax: 0.000240
# Train Epoch: 86 [20000/60000 (33%)]	Losses softmax: 0.000183 log_softmax: 0.000234
# Train Epoch: 86 [30000/60000 (50%)]	Losses softmax: 0.000300 log_softmax: 0.000443
# Train Epoch: 86 [40000/60000 (67%)]	Losses softmax: 0.000192 log_softmax: 0.000225
# Train Epoch: 86 [50000/60000 (83%)]	Losses softmax: 0.000229 log_softmax: 0.000340
# Train Epoch: 86 [60000/60000 (100%)]	Losses softmax: 0.000227 log_softmax: 0.000228
# Test set:
# softmax: Loss: 0.0803	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0865	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 87 [0/60000 (0%)]	Losses softmax: 0.000088 log_softmax: 0.000146
# Train Epoch: 87 [10000/60000 (17%)]	Losses softmax: 0.000249 log_softmax: 0.000204
# Train Epoch: 87 [20000/60000 (33%)]	Losses softmax: 0.000399 log_softmax: 0.000295
# Train Epoch: 87 [30000/60000 (50%)]	Losses softmax: 0.000295 log_softmax: 0.000189
# Train Epoch: 87 [40000/60000 (67%)]	Losses softmax: 0.000072 log_softmax: 0.000114
# Train Epoch: 87 [50000/60000 (83%)]	Losses softmax: 0.000432 log_softmax: 0.000309
# Train Epoch: 87 [60000/60000 (100%)]	Losses softmax: 0.000312 log_softmax: 0.000187
# Test set:
# softmax: Loss: 0.0805	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0867	Accuracy: 9794.0/10000 (98%)
#
# Train Epoch: 88 [0/60000 (0%)]	Losses softmax: 0.000720 log_softmax: 0.000404
# Train Epoch: 88 [10000/60000 (17%)]	Losses softmax: 0.000133 log_softmax: 0.000191
# Train Epoch: 88 [20000/60000 (33%)]	Losses softmax: 0.000339 log_softmax: 0.000209
# Train Epoch: 88 [30000/60000 (50%)]	Losses softmax: 0.000380 log_softmax: 0.000358
# Train Epoch: 88 [40000/60000 (67%)]	Losses softmax: 0.000180 log_softmax: 0.000260
# Train Epoch: 88 [50000/60000 (83%)]	Losses softmax: 0.000098 log_softmax: 0.000249
# Train Epoch: 88 [60000/60000 (100%)]	Losses softmax: 0.000651 log_softmax: 0.000572
# Test set:
# softmax: Loss: 0.0808	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0867	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 89 [0/60000 (0%)]	Losses softmax: 0.000308 log_softmax: 0.000218
# Train Epoch: 89 [10000/60000 (17%)]	Losses softmax: 0.000371 log_softmax: 0.000366
# Train Epoch: 89 [20000/60000 (33%)]	Losses softmax: 0.000096 log_softmax: 0.000246
# Train Epoch: 89 [30000/60000 (50%)]	Losses softmax: 0.000317 log_softmax: 0.000180
# Train Epoch: 89 [40000/60000 (67%)]	Losses softmax: 0.000167 log_softmax: 0.000261
# Train Epoch: 89 [50000/60000 (83%)]	Losses softmax: 0.000059 log_softmax: 0.000030
# Train Epoch: 89 [60000/60000 (100%)]	Losses softmax: 0.000078 log_softmax: 0.000096
# Test set:
# softmax: Loss: 0.0806	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0868	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 90 [0/60000 (0%)]	Losses softmax: 0.000149 log_softmax: 0.000360
# Train Epoch: 90 [10000/60000 (17%)]	Losses softmax: 0.000084 log_softmax: 0.000076
# Train Epoch: 90 [20000/60000 (33%)]	Losses softmax: 0.000375 log_softmax: 0.000324
# Train Epoch: 90 [30000/60000 (50%)]	Losses softmax: 0.000303 log_softmax: 0.000434
# Train Epoch: 90 [40000/60000 (67%)]	Losses softmax: 0.000350 log_softmax: 0.000174
# Train Epoch: 90 [50000/60000 (83%)]	Losses softmax: 0.000172 log_softmax: 0.000210
# Train Epoch: 90 [60000/60000 (100%)]	Losses softmax: 0.000385 log_softmax: 0.000524
# Test set:
# softmax: Loss: 0.0807	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0868	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 91 [0/60000 (0%)]	Losses softmax: 0.000093 log_softmax: 0.000133
# Train Epoch: 91 [10000/60000 (17%)]	Losses softmax: 0.000226 log_softmax: 0.000134
# Train Epoch: 91 [20000/60000 (33%)]	Losses softmax: 0.000159 log_softmax: 0.000256
# Train Epoch: 91 [30000/60000 (50%)]	Losses softmax: 0.000033 log_softmax: 0.000085
# Train Epoch: 91 [40000/60000 (67%)]	Losses softmax: 0.000078 log_softmax: 0.000103
# Train Epoch: 91 [50000/60000 (83%)]	Losses softmax: 0.000123 log_softmax: 0.000188
# Train Epoch: 91 [60000/60000 (100%)]	Losses softmax: 0.000118 log_softmax: 0.000211
# Test set:
# softmax: Loss: 0.0810	Accuracy: 9801.0/10000 (98%)
# log_softmax: Loss: 0.0870	Accuracy: 9790.0/10000 (98%)
#
# Train Epoch: 92 [0/60000 (0%)]	Losses softmax: 0.000025 log_softmax: 0.000080
# Train Epoch: 92 [10000/60000 (17%)]	Losses softmax: 0.000494 log_softmax: 0.000672
# Train Epoch: 92 [20000/60000 (33%)]	Losses softmax: 0.000185 log_softmax: 0.000117
# Train Epoch: 92 [30000/60000 (50%)]	Losses softmax: 0.000273 log_softmax: 0.000421
# Train Epoch: 92 [40000/60000 (67%)]	Losses softmax: 0.000060 log_softmax: 0.000083
# Train Epoch: 92 [50000/60000 (83%)]	Losses softmax: 0.000069 log_softmax: 0.000095
# Train Epoch: 92 [60000/60000 (100%)]	Losses softmax: 0.000173 log_softmax: 0.000189
# Test set:
# softmax: Loss: 0.0809	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0868	Accuracy: 9793.0/10000 (98%)
#
# Train Epoch: 93 [0/60000 (0%)]	Losses softmax: 0.000090 log_softmax: 0.000081
# Train Epoch: 93 [10000/60000 (17%)]	Losses softmax: 0.000120 log_softmax: 0.000115
# Train Epoch: 93 [20000/60000 (33%)]	Losses softmax: 0.000089 log_softmax: 0.000097
# Train Epoch: 93 [30000/60000 (50%)]	Losses softmax: 0.000182 log_softmax: 0.000206
# Train Epoch: 93 [40000/60000 (67%)]	Losses softmax: 0.000298 log_softmax: 0.000371
# Train Epoch: 93 [50000/60000 (83%)]	Losses softmax: 0.000065 log_softmax: 0.000102
# Train Epoch: 93 [60000/60000 (100%)]	Losses softmax: 0.000294 log_softmax: 0.000305
# Test set:
# softmax: Loss: 0.0809	Accuracy: 9805.0/10000 (98%)
# log_softmax: Loss: 0.0870	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 94 [0/60000 (0%)]	Losses softmax: 0.000081 log_softmax: 0.000189
# Train Epoch: 94 [10000/60000 (17%)]	Losses softmax: 0.000040 log_softmax: 0.000122
# Train Epoch: 94 [20000/60000 (33%)]	Losses softmax: 0.000225 log_softmax: 0.000287
# Train Epoch: 94 [30000/60000 (50%)]	Losses softmax: 0.000140 log_softmax: 0.000205
# Train Epoch: 94 [40000/60000 (67%)]	Losses softmax: 0.000243 log_softmax: 0.000157
# Train Epoch: 94 [50000/60000 (83%)]	Losses softmax: 0.000459 log_softmax: 0.000518
# Train Epoch: 94 [60000/60000 (100%)]	Losses softmax: 0.000108 log_softmax: 0.000173
# Test set:
# softmax: Loss: 0.0811	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0873	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 95 [0/60000 (0%)]	Losses softmax: 0.000113 log_softmax: 0.000030
# Train Epoch: 95 [10000/60000 (17%)]	Losses softmax: 0.000205 log_softmax: 0.000181
# Train Epoch: 95 [20000/60000 (33%)]	Losses softmax: 0.000477 log_softmax: 0.000579
# Train Epoch: 95 [30000/60000 (50%)]	Losses softmax: 0.000618 log_softmax: 0.000351
# Train Epoch: 95 [40000/60000 (67%)]	Losses softmax: 0.000123 log_softmax: 0.000186
# Train Epoch: 95 [50000/60000 (83%)]	Losses softmax: 0.000111 log_softmax: 0.000107
# Train Epoch: 95 [60000/60000 (100%)]	Losses softmax: 0.000625 log_softmax: 0.000642
# Test set:
# softmax: Loss: 0.0811	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0873	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 96 [0/60000 (0%)]	Losses softmax: 0.000143 log_softmax: 0.000109
# Train Epoch: 96 [10000/60000 (17%)]	Losses softmax: 0.000273 log_softmax: 0.000346
# Train Epoch: 96 [20000/60000 (33%)]	Losses softmax: 0.000164 log_softmax: 0.000195
# Train Epoch: 96 [30000/60000 (50%)]	Losses softmax: 0.000084 log_softmax: 0.000222
# Train Epoch: 96 [40000/60000 (67%)]	Losses softmax: 0.000042 log_softmax: 0.000072
# Train Epoch: 96 [50000/60000 (83%)]	Losses softmax: 0.000092 log_softmax: 0.000174
# Train Epoch: 96 [60000/60000 (100%)]	Losses softmax: 0.000154 log_softmax: 0.000160
# Test set:
# softmax: Loss: 0.0814	Accuracy: 9800.0/10000 (98%)
# log_softmax: Loss: 0.0874	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 97 [0/60000 (0%)]	Losses softmax: 0.000075 log_softmax: 0.000042
# Train Epoch: 97 [10000/60000 (17%)]	Losses softmax: 0.000124 log_softmax: 0.000154
# Train Epoch: 97 [20000/60000 (33%)]	Losses softmax: 0.000078 log_softmax: 0.000097
# Train Epoch: 97 [30000/60000 (50%)]	Losses softmax: 0.000330 log_softmax: 0.000365
# Train Epoch: 97 [40000/60000 (67%)]	Losses softmax: 0.000035 log_softmax: 0.000049
# Train Epoch: 97 [50000/60000 (83%)]	Losses softmax: 0.000182 log_softmax: 0.000136
# Train Epoch: 97 [60000/60000 (100%)]	Losses softmax: 0.000084 log_softmax: 0.000079
# Test set:
# softmax: Loss: 0.0813	Accuracy: 9804.0/10000 (98%)
# log_softmax: Loss: 0.0874	Accuracy: 9796.0/10000 (98%)
#
# Train Epoch: 98 [0/60000 (0%)]	Losses softmax: 0.000055 log_softmax: 0.000106
# Train Epoch: 98 [10000/60000 (17%)]	Losses softmax: 0.000146 log_softmax: 0.000193
# Train Epoch: 98 [20000/60000 (33%)]	Losses softmax: 0.000416 log_softmax: 0.000407
# Train Epoch: 98 [30000/60000 (50%)]	Losses softmax: 0.000178 log_softmax: 0.000099
# Train Epoch: 98 [40000/60000 (67%)]	Losses softmax: 0.000256 log_softmax: 0.000306
# Train Epoch: 98 [50000/60000 (83%)]	Losses softmax: 0.000511 log_softmax: 0.000601
# Train Epoch: 98 [60000/60000 (100%)]	Losses softmax: 0.000220 log_softmax: 0.000060
# Test set:
# softmax: Loss: 0.0814	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0875	Accuracy: 9791.0/10000 (98%)
#
# Train Epoch: 99 [0/60000 (0%)]	Losses softmax: 0.000079 log_softmax: 0.000105
# Train Epoch: 99 [10000/60000 (17%)]	Losses softmax: 0.000107 log_softmax: 0.000085
# Train Epoch: 99 [20000/60000 (33%)]	Losses softmax: 0.000324 log_softmax: 0.000309
# Train Epoch: 99 [30000/60000 (50%)]	Losses softmax: 0.000321 log_softmax: 0.000441
# Train Epoch: 99 [40000/60000 (67%)]	Losses softmax: 0.000183 log_softmax: 0.000308
# Train Epoch: 99 [50000/60000 (83%)]	Losses softmax: 0.000329 log_softmax: 0.000526
# Train Epoch: 99 [60000/60000 (100%)]	Losses softmax: 0.000051 log_softmax: 0.000160
# Test set:
# softmax: Loss: 0.0813	Accuracy: 9803.0/10000 (98%)
# log_softmax: Loss: 0.0876	Accuracy: 9792.0/10000 (98%)
#
# Train Epoch: 100 [0/60000 (0%)]	Losses softmax: 0.000171 log_softmax: 0.000240
# Train Epoch: 100 [10000/60000 (17%)]	Losses softmax: 0.000163 log_softmax: 0.000139
# Train Epoch: 100 [20000/60000 (33%)]	Losses softmax: 0.000205 log_softmax: 0.000172
# Train Epoch: 100 [30000/60000 (50%)]	Losses softmax: 0.000208 log_softmax: 0.000173
# Train Epoch: 100 [40000/60000 (67%)]	Losses softmax: 0.000065 log_softmax: 0.000044
# Train Epoch: 100 [50000/60000 (83%)]	Losses softmax: 0.000090 log_softmax: 0.000060
# Train Epoch: 100 [60000/60000 (100%)]	Losses softmax: 0.000099 log_softmax: 0.000055
# Test set:
# softmax: Loss: 0.0814	Accuracy: 9802.0/10000 (98%)
# log_softmax: Loss: 0.0877	Accuracy: 9794.0/10000 (98%)

# %%
test_loss_softmax = [i[0] for i in test_log['softmax']]
test_acc_softmax = [i[1] for i in test_log['softmax']]
test_loss_log_softmax = [i[0] for i in test_log['log_softmax']]
test_acc_log_softmax = [i[1] for i in test_log['log_softmax']]

plt.figure(figsize=(12, 5))
plt.plot(range(0, epochs), test_loss_softmax)
plt.xticks(range(0, epochs, 5))
plt.ylabel('loss')
plt.grid()

plt.figure(figsize=(12, 5))
plt.plot(range(0, epochs), test_acc_softmax)
plt.xlabel('epochs')
plt.xticks(range(0, epochs, 5))
plt.ylabel('accuracy')
plt.grid()

# %%
test_loss_softmax = [i[0] for i in test_log['softmax']]
test_acc_softmax = [i[1] for i in test_log['softmax']]
test_loss_log_softmax = [i[0] for i in test_log['log_softmax']]
test_acc_log_softmax = [i[1] for i in test_log['log_softmax']]

plt.figure(figsize=(12, 5))
plt.plot(range(0, epochs), test_loss_softmax)
plt.xticks(range(0, epochs, 2))
plt.xlim((0, 50))
plt.ylim((0.06, 0.13))
plt.ylabel('loss')
plt.grid()

plt.figure(figsize=(12, 5))
plt.plot(range(0, epochs), test_acc_softmax)
plt.xlabel('epochs')
plt.xticks(range(0, epochs, 2))
plt.xlim((0, 50))
plt.ylim((96, 98.5))
plt.ylabel('accuracy')
plt.grid()

# %%
test_loss_softmax[49]
# Out:
# 0.07719257820115599
